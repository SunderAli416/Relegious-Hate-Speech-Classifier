# %%
from sklearn.metrics import confusion_matrix,classification_report
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
from tensorflow.keras import regularizers
import numpy as np
from nltk.stem import SnowballStemmer
import re
import tensorflow as tf
import pickle
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# Mounted at /content/drive
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df = pd.read_csv('/Data/train_data.csv')
df.columns
df['label'] = df['label'].replace({"hate":0,"nothate":1})

# %%
def preprocess_text(df):
  df['text'] = df['text'].str.lower()
  df['text'] = df['text'].apply(lambda x: re.sub('[^a-zA-Z]', ' ', x))
  df['text'] = df['text'].apply(lambda x: x.split())
  stop_words = set(stopwords.words('english'))
  df['text'] = df['text'].apply(lambda x: [word for word in x if word not in stop_words])
  stemmer = SnowballStemmer('english')
  df['text'] = df['text'].apply(lambda x: [stemmer.stem(word) for word in x])
  df['text'] = df['text'].apply(lambda x: ' '.join(x))
  return df['text']
max_length = 1000

# %%
df['text'] = preprocess_text(df)

char_set = 'abcdefghijklmnopqrstuvwxyz0123456789,;.!?:’"/\\|_@#$%^&*~‘+-=<>()[]{} \n'
char_to_index = {char: index for index, char in enumerate(char_set)}

X = []
for sentence in df['text']:
    encoded_sentence = np.zeros((max_length, len(char_set)))
    for i, char in enumerate(sentence):
        if i >= max_length:
            break
        if char in char_set:
            encoded_sentence[i, char_to_index[char]] = 1
    X.append(encoded_sentence)
X = np.array(X)

# %%
print(X.shape)
len(X[0])
# Out:
# (3004, 1000, 70)
# 1000

# %%
checkpoint_filepath = '/Models/CharacterLevel/characterlevel_3000.h5'
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

# %% [markdown]
# ## Model Summary
#
#
#
# ```plaintext
# Input shape: (1000, 70)
#
# Layer (type)                     Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)             [(None, 1000, 70)]   0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                  (None, 996, 128)     44928       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)     (None, 249, 128)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)                (None, 245, 256)     164096      max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)   (None, 61, 256)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)                (None, 57, 512)      655872      max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)   (None, 14, 512)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)                (None, 7168)         0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                    (None, 512)          3670528     flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)                (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 256)          131328      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 4,034,009
# Trainable params: 4,034,009
# Non-trainable params: 0

# %%
input_shape = (1000,70)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Conv1D(256, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Conv1D(512, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X,df['label'],validation_split = 0.1, epochs=100, batch_size=32,callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 85/85 [==============================] - ETA: 0s - loss: 2.8039 - accuracy: 0.6637
# Epoch 1: val_accuracy improved from -inf to 0.68771, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 19s 41ms/step - loss: 2.8039 - accuracy: 0.6637 - val_loss: 0.8618 - val_accuracy: 0.6877
# Epoch 2/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.7159 - accuracy: 0.7063
# Epoch 2: val_accuracy improved from 0.68771 to 0.71429, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 2s 25ms/step - loss: 0.7140 - accuracy: 0.7063 - val_loss: 0.6660 - val_accuracy: 0.7143
# Epoch 3/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.5450 - accuracy: 0.7797
# Epoch 3: val_accuracy improved from 0.71429 to 0.73754, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 2s 27ms/step - loss: 0.5467 - accuracy: 0.7791 - val_loss: 0.5782 - val_accuracy: 0.7375
# Epoch 4/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.4228 - accuracy: 0.8478
# Epoch 4: val_accuracy improved from 0.73754 to 0.78738, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 2s 22ms/step - loss: 0.4236 - accuracy: 0.8472 - val_loss: 0.5440 - val_accuracy: 0.7874
# Epoch 5/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.3512 - accuracy: 0.8829
# Epoch 5: val_accuracy did not improve from 0.78738
# 85/85 [==============================] - 2s 19ms/step - loss: 0.3504 - accuracy: 0.8835 - val_loss: 0.6095 - val_accuracy: 0.7608
# Epoch 6/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.2703 - accuracy: 0.9145
# Epoch 6: val_accuracy did not improve from 0.78738
# 85/85 [==============================] - 1s 17ms/step - loss: 0.2689 - accuracy: 0.9153 - val_loss: 0.6518 - val_accuracy: 0.7708
# Epoch 7/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.2051 - accuracy: 0.9450
# Epoch 7: val_accuracy improved from 0.78738 to 0.79402, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 2s 20ms/step - loss: 0.2084 - accuracy: 0.9434 - val_loss: 0.7483 - val_accuracy: 0.7940
# Epoch 8/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.2100 - accuracy: 0.9520
# Epoch 8: val_accuracy did not improve from 0.79402
# 85/85 [==============================] - 1s 17ms/step - loss: 0.2098 - accuracy: 0.9519 - val_loss: 0.6577 - val_accuracy: 0.7708
# Epoch 9/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.1371 - accuracy: 0.9706
# Epoch 9: val_accuracy did not improve from 0.79402
# 85/85 [==============================] - 1s 17ms/step - loss: 0.1367 - accuracy: 0.9708 - val_loss: 0.6864 - val_accuracy: 0.7874
# Epoch 10/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.1099 - accuracy: 0.9816
# Epoch 10: val_accuracy improved from 0.79402 to 0.80066, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 2s 19ms/step - loss: 0.1108 - accuracy: 0.9808 - val_loss: 0.7738 - val_accuracy: 0.8007
# Epoch 11/100
# 85/85 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.9797
# Epoch 11: val_accuracy did not improve from 0.80066
# 85/85 [==============================] - 2s 23ms/step - loss: 0.1123 - accuracy: 0.9797 - val_loss: 0.9040 - val_accuracy: 0.7973
# Epoch 12/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.1320 - accuracy: 0.9752
# Epoch 12: val_accuracy did not improve from 0.80066
# 85/85 [==============================] - 2s 19ms/step - loss: 0.1310 - accuracy: 0.9756 - val_loss: 0.8232 - val_accuracy: 0.7874
# Epoch 13/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0806 - accuracy: 0.9906
# Epoch 13: val_accuracy improved from 0.80066 to 0.81395, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0806 - accuracy: 0.9908 - val_loss: 0.8198 - val_accuracy: 0.8140
# Epoch 14/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9874
# Epoch 14: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0777 - accuracy: 0.9874 - val_loss: 0.8378 - val_accuracy: 0.8140
# Epoch 15/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9941
# Epoch 15: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 1s 18ms/step - loss: 0.0588 - accuracy: 0.9941 - val_loss: 0.9097 - val_accuracy: 0.8040
# Epoch 16/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9963
# Epoch 16: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 2s 20ms/step - loss: 0.0412 - accuracy: 0.9959 - val_loss: 0.8224 - val_accuracy: 0.8106
# Epoch 17/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9970
# Epoch 17: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0355 - accuracy: 0.9970 - val_loss: 0.8923 - val_accuracy: 0.7940
# Epoch 18/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9952
# Epoch 18: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0545 - accuracy: 0.9952 - val_loss: 0.9884 - val_accuracy: 0.8073
# Epoch 19/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9877
# Epoch 19: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 2s 21ms/step - loss: 0.1055 - accuracy: 0.9878 - val_loss: 0.9574 - val_accuracy: 0.8040
# Epoch 20/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9887
# Epoch 20: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0818 - accuracy: 0.9885 - val_loss: 0.9450 - val_accuracy: 0.7774
# Epoch 21/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0979 - accuracy: 0.9853
# Epoch 21: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0980 - accuracy: 0.9852 - val_loss: 1.0598 - val_accuracy: 0.7973
# Epoch 22/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0972 - accuracy: 0.9848
# Epoch 22: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0998 - accuracy: 0.9841 - val_loss: 0.9316 - val_accuracy: 0.7940
# Epoch 23/100
# 85/85 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9848
# Epoch 23: val_accuracy did not improve from 0.81395
# 85/85 [==============================] - 2s 20ms/step - loss: 0.1220 - accuracy: 0.9848 - val_loss: 0.9050 - val_accuracy: 0.8140
# Epoch 24/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9922
# Epoch 24: val_accuracy improved from 0.81395 to 0.82060, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0663 - accuracy: 0.9922 - val_loss: 0.8669 - val_accuracy: 0.8206
# Epoch 25/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0438 - accuracy: 0.9966
# Epoch 25: val_accuracy did not improve from 0.82060
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0433 - accuracy: 0.9967 - val_loss: 1.0979 - val_accuracy: 0.8206
# Epoch 26/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0855 - accuracy: 0.9950
# Epoch 26: val_accuracy improved from 0.82060 to 0.82724, saving model to /content/drive/MyDrive/FYP-DATA-AND-RESOURCES/Models_and_data/CharacterLevel/characterlevel_3000.h5
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0845 - accuracy: 0.9952 - val_loss: 0.9113 - val_accuracy: 0.8272
# Epoch 27/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9978
# Epoch 27: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0375 - accuracy: 0.9978 - val_loss: 0.9082 - val_accuracy: 0.8040
# Epoch 28/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9985
# Epoch 28: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0237 - accuracy: 0.9985 - val_loss: 0.8933 - val_accuracy: 0.8272
# Epoch 29/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9977
# Epoch 29: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0204 - accuracy: 0.9978 - val_loss: 0.8700 - val_accuracy: 0.8073
# Epoch 30/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9970
# Epoch 30: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0302 - accuracy: 0.9970 - val_loss: 0.9839 - val_accuracy: 0.8239
# Epoch 31/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9930
# Epoch 31: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0733 - accuracy: 0.9930 - val_loss: 1.0085 - val_accuracy: 0.8206
# Epoch 32/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9962
# Epoch 32: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 20ms/step - loss: 0.0440 - accuracy: 0.9963 - val_loss: 1.0883 - val_accuracy: 0.8040
# Epoch 33/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9974
# Epoch 33: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0232 - accuracy: 0.9974 - val_loss: 0.9774 - val_accuracy: 0.8173
# Epoch 34/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0694 - accuracy: 0.9935
# Epoch 34: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0714 - accuracy: 0.9937 - val_loss: 1.2816 - val_accuracy: 0.8272
# Epoch 35/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.1837 - accuracy: 0.9774
# Epoch 35: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 24ms/step - loss: 0.1815 - accuracy: 0.9778 - val_loss: 0.9754 - val_accuracy: 0.8040
# Epoch 36/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0597 - accuracy: 0.9954
# Epoch 36: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0589 - accuracy: 0.9956 - val_loss: 0.9971 - val_accuracy: 0.8173
# Epoch 37/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0373 - accuracy: 0.9963
# Epoch 37: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0373 - accuracy: 0.9963 - val_loss: 1.3550 - val_accuracy: 0.7774
# Epoch 38/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.9951
# Epoch 38: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0417 - accuracy: 0.9952 - val_loss: 1.2641 - val_accuracy: 0.7940
# Epoch 39/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.1425 - accuracy: 0.9857
# Epoch 39: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.1418 - accuracy: 0.9859 - val_loss: 1.2818 - val_accuracy: 0.7907
# Epoch 40/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9978
# Epoch 40: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0631 - accuracy: 0.9978 - val_loss: 1.2366 - val_accuracy: 0.7973
# Epoch 41/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9974
# Epoch 41: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0325 - accuracy: 0.9974 - val_loss: 1.1099 - val_accuracy: 0.8040
# Epoch 42/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9872
# Epoch 42: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0666 - accuracy: 0.9874 - val_loss: 1.0778 - val_accuracy: 0.7475
# Epoch 43/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.9898
# Epoch 43: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0617 - accuracy: 0.9900 - val_loss: 1.1843 - val_accuracy: 0.8007
# Epoch 44/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9900
# Epoch 44: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0567 - accuracy: 0.9900 - val_loss: 1.1872 - val_accuracy: 0.8007
# Epoch 45/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0765 - accuracy: 0.9921
# Epoch 45: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0767 - accuracy: 0.9919 - val_loss: 1.0685 - val_accuracy: 0.7973
# Epoch 46/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0457 - accuracy: 0.9970
# Epoch 46: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0456 - accuracy: 0.9970 - val_loss: 1.0491 - val_accuracy: 0.7874
# Epoch 47/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0459 - accuracy: 0.9977
# Epoch 47: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0453 - accuracy: 0.9978 - val_loss: 1.0278 - val_accuracy: 0.8206
# Epoch 48/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9985
# Epoch 48: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0315 - accuracy: 0.9985 - val_loss: 1.0264 - val_accuracy: 0.8173
# Epoch 49/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9985
# Epoch 49: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0186 - accuracy: 0.9985 - val_loss: 0.9895 - val_accuracy: 0.8206
# Epoch 50/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9982
# Epoch 50: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0162 - accuracy: 0.9982 - val_loss: 0.9489 - val_accuracy: 0.8239
# Epoch 51/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9963
# Epoch 51: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0300 - accuracy: 0.9963 - val_loss: 1.3299 - val_accuracy: 0.7973
# Epoch 52/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0272 - accuracy: 0.9989
# Epoch 52: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0273 - accuracy: 0.9989 - val_loss: 1.0815 - val_accuracy: 0.8073
# Epoch 53/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9989
# Epoch 53: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0160 - accuracy: 0.9985 - val_loss: 1.0587 - val_accuracy: 0.8206
# Epoch 54/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9993
# Epoch 54: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0127 - accuracy: 0.9989 - val_loss: 1.0578 - val_accuracy: 0.8140
# Epoch 55/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9985
# Epoch 55: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 20ms/step - loss: 0.0135 - accuracy: 0.9985 - val_loss: 1.0827 - val_accuracy: 0.8073
# Epoch 56/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9981
# Epoch 56: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0131 - accuracy: 0.9982 - val_loss: 1.0490 - val_accuracy: 0.8206
# Epoch 57/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9974
# Epoch 57: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0144 - accuracy: 0.9974 - val_loss: 1.0665 - val_accuracy: 0.7907
# Epoch 58/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9911
# Epoch 58: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0697 - accuracy: 0.9911 - val_loss: 1.3210 - val_accuracy: 0.7807
# Epoch 59/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0901 - accuracy: 0.9920
# Epoch 59: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0903 - accuracy: 0.9922 - val_loss: 1.3088 - val_accuracy: 0.7940
# Epoch 60/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0884 - accuracy: 0.9874
# Epoch 60: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 27ms/step - loss: 0.0881 - accuracy: 0.9874 - val_loss: 1.2722 - val_accuracy: 0.7940
# Epoch 61/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9808
# Epoch 61: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 3s 30ms/step - loss: 0.0986 - accuracy: 0.9808 - val_loss: 0.9812 - val_accuracy: 0.8140
# Epoch 62/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9955
# Epoch 62: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0454 - accuracy: 0.9956 - val_loss: 1.1622 - val_accuracy: 0.8040
# Epoch 63/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0679 - accuracy: 0.9959
# Epoch 63: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0680 - accuracy: 0.9956 - val_loss: 1.1552 - val_accuracy: 0.8073
# Epoch 64/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0578 - accuracy: 0.9947
# Epoch 64: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0596 - accuracy: 0.9941 - val_loss: 1.0502 - val_accuracy: 0.7973
# Epoch 65/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9967
# Epoch 65: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0399 - accuracy: 0.9967 - val_loss: 1.1190 - val_accuracy: 0.8106
# Epoch 66/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9985
# Epoch 66: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0198 - accuracy: 0.9985 - val_loss: 1.2016 - val_accuracy: 0.8173
# Epoch 67/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9941
# Epoch 67: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0906 - accuracy: 0.9941 - val_loss: 1.4412 - val_accuracy: 0.8007
# Epoch 68/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0449 - accuracy: 0.9981
# Epoch 68: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0444 - accuracy: 0.9982 - val_loss: 1.2675 - val_accuracy: 0.8040
# Epoch 69/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 0.9989
# Epoch 69: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0222 - accuracy: 0.9989 - val_loss: 1.2601 - val_accuracy: 0.7940
# Epoch 70/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9992
# Epoch 70: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0148 - accuracy: 0.9993 - val_loss: 1.2005 - val_accuracy: 0.8106
# Epoch 71/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9937
# Epoch 71: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 27ms/step - loss: 0.0899 - accuracy: 0.9937 - val_loss: 1.4738 - val_accuracy: 0.8007
# Epoch 72/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9959
# Epoch 72: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0937 - accuracy: 0.9959 - val_loss: 1.2110 - val_accuracy: 0.8040
# Epoch 73/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0520 - accuracy: 0.9978
# Epoch 73: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0519 - accuracy: 0.9978 - val_loss: 1.2702 - val_accuracy: 0.8040
# Epoch 74/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0259 - accuracy: 0.9981
# Epoch 74: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0257 - accuracy: 0.9982 - val_loss: 1.2935 - val_accuracy: 0.7973
# Epoch 75/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0163 - accuracy: 0.9981
# Epoch 75: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0163 - accuracy: 0.9982 - val_loss: 1.1996 - val_accuracy: 0.7940
# Epoch 76/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9993
# Epoch 76: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0153 - accuracy: 0.9993 - val_loss: 1.1804 - val_accuracy: 0.7973
# Epoch 77/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9978
# Epoch 77: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0127 - accuracy: 0.9978 - val_loss: 1.2290 - val_accuracy: 0.8007
# Epoch 78/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9977
# Epoch 78: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0109 - accuracy: 0.9978 - val_loss: 1.1621 - val_accuracy: 0.8106
# Epoch 79/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9985
# Epoch 79: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0095 - accuracy: 0.9985 - val_loss: 1.2428 - val_accuracy: 0.7973
# Epoch 80/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9985
# Epoch 80: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0121 - accuracy: 0.9985 - val_loss: 1.3040 - val_accuracy: 0.7841
# Epoch 81/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9985
# Epoch 81: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0090 - accuracy: 0.9985 - val_loss: 1.1461 - val_accuracy: 0.8040
# Epoch 82/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9978
# Epoch 82: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0191 - accuracy: 0.9970 - val_loss: 1.4261 - val_accuracy: 0.7807
# Epoch 83/100
# 85/85 [==============================] - ETA: 0s - loss: 0.2060 - accuracy: 0.9656
# Epoch 83: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.2060 - accuracy: 0.9656 - val_loss: 1.2026 - val_accuracy: 0.7542
# Epoch 84/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.1452 - accuracy: 0.9880
# Epoch 84: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.1452 - accuracy: 0.9878 - val_loss: 1.3682 - val_accuracy: 0.7874
# Epoch 85/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9951
# Epoch 85: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0693 - accuracy: 0.9952 - val_loss: 1.2580 - val_accuracy: 0.8140
# Epoch 86/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0339 - accuracy: 0.9989
# Epoch 86: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 20ms/step - loss: 0.0336 - accuracy: 0.9989 - val_loss: 1.2242 - val_accuracy: 0.8206
# Epoch 87/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0225 - accuracy: 0.9981
# Epoch 87: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0229 - accuracy: 0.9978 - val_loss: 1.2172 - val_accuracy: 0.8272
# Epoch 88/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9992
# Epoch 88: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0167 - accuracy: 0.9993 - val_loss: 1.2408 - val_accuracy: 0.8173
# Epoch 89/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9974
# Epoch 89: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0473 - accuracy: 0.9974 - val_loss: 1.2698 - val_accuracy: 0.8040
# Epoch 90/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0730 - accuracy: 0.9981
# Epoch 90: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0724 - accuracy: 0.9982 - val_loss: 1.3212 - val_accuracy: 0.8173
# Epoch 91/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9989
# Epoch 91: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0259 - accuracy: 0.9989 - val_loss: 1.2494 - val_accuracy: 0.8206
# Epoch 92/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9967
# Epoch 92: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0179 - accuracy: 0.9967 - val_loss: 1.1403 - val_accuracy: 0.8173
# Epoch 93/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9985
# Epoch 93: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0131 - accuracy: 0.9985 - val_loss: 1.1709 - val_accuracy: 0.8173
# Epoch 94/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9981
# Epoch 94: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0114 - accuracy: 0.9982 - val_loss: 1.1559 - val_accuracy: 0.8173
# Epoch 95/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9974
# Epoch 95: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0175 - accuracy: 0.9974 - val_loss: 1.3692 - val_accuracy: 0.8040
# Epoch 96/100
# 84/85 [============================>.] - ETA: 0s - loss: 0.1236 - accuracy: 0.9840
# Epoch 96: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.1241 - accuracy: 0.9837 - val_loss: 1.4265 - val_accuracy: 0.7841
# Epoch 97/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1420 - accuracy: 0.9729
# Epoch 97: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 2s 18ms/step - loss: 0.1407 - accuracy: 0.9734 - val_loss: 1.3125 - val_accuracy: 0.8040
# Epoch 98/100
# 82/85 [===========================>..] - ETA: 0s - loss: 0.0588 - accuracy: 0.9924
# Epoch 98: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0581 - accuracy: 0.9926 - val_loss: 1.2155 - val_accuracy: 0.7973
# Epoch 99/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9966
# Epoch 99: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 18ms/step - loss: 0.0328 - accuracy: 0.9967 - val_loss: 1.3118 - val_accuracy: 0.8040
# Epoch 100/100
# 83/85 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9981
# Epoch 100: val_accuracy did not improve from 0.82724
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0223 - accuracy: 0.9982 - val_loss: 1.2696 - val_accuracy: 0.8007

# %%
df2 = pd.read_csv('/Data/test_data.csv')
df2['label'] = df2['label'].replace({"hate":0,"nothate":1})
df2['text'] = preprocess_text(df2)

char_set = 'abcdefghijklmnopqrstuvwxyz0123456789,;.!?:’"/\\|_@#$%^&*~‘+-=<>()[]{} \n'
char_to_index = {char: index for index, char in enumerate(char_set)}

X2 = []
for sentence in df2['text']:
    encoded_sentence = np.zeros((max_length, len(char_set)))
    for i, char in enumerate(sentence):
        if i >= max_length:
            break
        if char in char_set:
            encoded_sentence[i, char_to_index[char]] = 1
    X2.append(encoded_sentence)
X2 = np.array(X2)

# %%
loaded_model = load_model('/Models/CharacterLevel/characterlevel_3000.h5')
pred = loaded_model.predict(X2)
loss, acc = loaded_model.evaluate(X2,df2['label'], batch_size=32)

print('Test loss:', loss)
print('Test accuracy:', acc,end = '\n\n')

for i,x in enumerate(pred):#['hate = 0' 'nothate = 1']
  if x >= 0.5:
    pred[i] = 1
  else:
    pred[i] = 0
cm = confusion_matrix(df2['label'],pred)
print(cm)
cr = classification_report(df2['label'],pred)
print(cr)
# Out:
# 11/11 [==============================] - 8s 17ms/step
# 11/11 [==============================] - 0s 11ms/step - loss: 0.5188 - accuracy: 0.8982
# Test loss: 0.5187922716140747
# Test accuracy: 0.8982036113739014
#
# [[172  17]
#  [ 17 128]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       189
#            1       0.88      0.88      0.88       145
#
#     accuracy                           0.90       334
#    macro avg       0.90      0.90      0.90       334
# weighted avg       0.90      0.90      0.90       334
